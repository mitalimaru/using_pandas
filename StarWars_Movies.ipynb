# %%
# import the package

from tabulate import tabulate

# Create data as a list of lists (each row has a student name, age, and exam grade)

data = [
	[ "Jacob", 18, "A" ],
	[ "Isabella", 19, "B" ],
	[ "Ethan", 18, "A" ],
	[ "Sophia", 19, "B" ],
	[ "Michael", 20, "C" ],
]

# create data for the column names

column_names = [ "name", "age", "grade" ]

# create the table

table = tabulate ( data, column_names, tablefmt = "grid" )

# print the table

print ()
print (table)
print ()
# Out:
# +----------+-------+---------+
# | name     |   age | grade   |
# +==========+=======+=========+
# | Jacob    |    18 | A       |
# +----------+-------+---------+
# | Isabella |    19 | B       |
# +----------+-------+---------+
# | Ethan    |    18 | A       |
# +----------+-------+---------+
# | Sophia   |    19 | B       |
# +----------+-------+---------+
# | Michael  |    20 | C       |
# +----------+-------+---------+

# %%
# import the package

from tabulate import tabulate

# Create data as a list of lists (each row has a student name, age, and exam grade)

data = [
	[ "Jacob", 18, "A" ],
	[ "Isabella", 19, "B" ],
	[ "Ethan", 18, "A" ],
	[ "Sophia", 19, "B" ],
	[ "Michael", 20, "C" ],
]

# create data for the column names

column_names = [ "name", "age", "grade" ]

# create the table

table = tabulate ( data, column_names, tablefmt = "markdown" )

# print the table

print ()
print (table)
print ()
# Out:
# name        age  grade
# --------  -----  -------
# Jacob        18  A
# Isabella     19  B
# Ethan        18  A
# Sophia       19  B
# Michael      20  C

# %%
# Activity - Star Wars Movie Titles
# --------------------------------------------------

# Create a list of the Star Wars movie titles (from the prequel, original, and sequel trilogies).

starWarsMovies = []
starWarsMovies.append ("Episode I - The Phantom Menace")
starWarsMovies.append ("Episode II - Attack of the Clones")
starWarsMovies.append ("Episode III - Revenge of the Sith")
starWarsMovies.append ("Episode IV - A New Hope")
starWarsMovies.append ("Episode V - The Empire Strikes Back")
starWarsMovies.append ("Episode VI - Return of the Jedi")
starWarsMovies.append ("Episode VII - The Force Awakens")
starWarsMovies.append ("Episode VIII - The Last Jedi")
starWarsMovies.append ("Episode IX - The Rise of Skywalker")

# Convert this list to a tuple.
# Store the tuple as a new variable.

# Display the movie title where Anakin first appeared.

# Try to change a value in the tuple.

# %%
starWarsMovies = tuple(starWarsMovies)

# %%
print(starWarsMovies)
# Out:
# (*tuple[['Episode I - The Phantom Menace', 'Episode II - Attack of the Clones', 'Episode III - Revenge of the Sith', 'Episode IV - A New Hope', 'Episode V - The Empire Strikes Back', 'Episode VI - Return of the Jedi', 'Episode VII - The Force Awakens', 'Episode VIII - The Last Jedi', 'Episode IX - The Rise of Skywalker']],)

# %%
print ()

# Activity 1 - Star Wars Movie Titles
# --------------------------------------------------

# Create a list of the Star Wars movie titles (from the prequel, original, and sequel trilogies).
starWarsMovies = []
starWarsMovies.append ("Episode I - The Phantom Menace")
starWarsMovies.append ("Episode II - Attack of the Clones")
starWarsMovies.append ("Episode III - Revenge of the Sith")
starWarsMovies.append ("Episode IV - A New Hope")
starWarsMovies.append ("Episode V - The Empire Strikes Back")
starWarsMovies.append ("Episode VI - Return of the Jedi")
starWarsMovies.append ("Episode VII - The Force Awakens")
starWarsMovies.append ("Episode VIII - The Last Jedi")
starWarsMovies.append ("Episode IX - The Rise of Skywalker")

# Convert this list to a tuple.
# Store the tuple as a new variable.
starWarsMoviesTuple = tuple (starWarsMovies)

# Display the movie title where Anakin first appeared.
print ("Anakin first appeared in \"{}\".".format (starWarsMoviesTuple [0]))
print ()

# Try to change a value in the tuple.
# starWarsMoviesTuple [0] = "New movie title"

# Activity 2 - Initial Anakin Dictionary
# --------------------------------------------------

# Create a new dictionary and store in anakinDictionary.
# Initialize the dictionary with the following data about Anakin Skywalker:
    # Name: Anakin Skywalker
    # Home World: Tatooine
    # Force Association: Jedi
    # Lightsaber Color: Blue
    # First Movie Appearance: Episode I - The Phantom Menace (Movie 1)
anakinDictionary = {
        "name": "Anakin Skywalker",
        "homeworld": "Tatooine",
        "association": "Jedi",
        "lightsaberColor": "Blue",
        "firstMovieAppearance": 1
    }

# Print the Anakin Dictionary.
print ("Anakin Dictionary:")
print (anakinDictionary)
print ()

# Activity 3 - Anakin Becomes Darth Vader
# --------------------------------------------------
# Update your dictionary to reflect these changes:

# Anakin becomes a Sith named Darth Vader.
anakinDictionary ["association"] = "Sith"
anakinDictionary ["name"] = "Darth Vader"

# He now resides on the world of Mustafar.
anakinDictionary ["homeworld"] = "Mustafar"

# He now carries a red lightsaber.
anakinDictionary ["lightsaberColor"] = "Red"

# Print the Anakin Dictionary.
print ("Anakin Dictionary:")
print (anakinDictionary)
print ()

# Activity 4 - First Movie Appearance Revisited
# --------------------------------------------------

# Display the movie where Anakin first appeared - dynamically.
print ("Anakin first appeared in \"{}\".".format (starWarsMoviesTuple [ anakinDictionary [ "firstMovieAppearance"] -1 ]))
print ()

# Activity 5 - Multiple Star Wars Characters
# --------------------------------------------------
# Create a tuple in charactersTuple with the following character names as strings: Anakin Skywalker, Luke Skywalker, Rey.
charactersTuple = ( "Anakin Skywalker", "Luke Skywalker", "Rey" )

# Create a list in charactersList to hold more complex data on multiple characters.
charactersList = []

# Iterate over the character names from the tuple.  For each name:
for characterName in charactersTuple:

    # Create a dictionary with a name key-value pair.
    thisCharacter = { "name": characterName  }
    
    # Append the dictionary to charactersList
    charactersList.append (thisCharacter)

# Print the Characters List of Dictionaries
print ("Characters List of Dictionaries:")
print (charactersList)
print ()

print ("Character Names:")

# Iterate over charactersList:
for character in charactersList:

    # Print out each character's name
    print (character ["name"])

print ()

# Activity 6 - Manipulating the List of Dictionaries
# --------------------------------------------------
# 1 of 5
# In your character list of dictionaries,
# overwrite the Darth Vader data with the Anakin dictionary.
charactersList [0] = anakinDictionary

# Print the Characters List of Dictionaries
print ("Characters List of Dictionaries:")
print (charactersList)
print ()

# 2 of 5
# Create a new dictionary in lukeDictionary.
# Initialize the dictionary with the following data about Luke Skywalker.
    # Name: Luke Skywalker
    # Home World: Tatooine
    # Force Association: Jedi
    # Lightsaber Color: Blue - Luke gets his first (blue) lightsaber from Obi-Wan
    # First Movie Appearance: Episode III - Revenge of the Sith (Movie 3)
lukeDictionary = {
        "name": "Luke Skywalker",
        "homeworld": "Tatooine",
        "association": "Jedi",
        "lightsaberColor": "Blue",
        "firstMovieAppearance": 3
    }

# In your character list of dictionaries, overwrite the Luke Skywalker data with this dictionary.
charactersList [1] = lukeDictionary

# Print the Characters List of Dictionaries
print ("Characters List of Dictionaries:")
print (charactersList)
print ()

# 3 of 5
# After his training with Yoda, Luke makes a new lightsaber, which is green.
# Modify the value in lukeDictionary (not charactersList) to reflect this change.
lukeDictionary ["lightsaberColor"] = "Green"

# Print the Characters List of Dictionaries
print ("Characters List of Dictionaries:")
print (charactersList)
print ()

# 4 of 5
# In the sequel trilogy, we learn about Rey.
# Do not create a new dictionary (as we did for Luke).
# Instead, add Rey's data directly to charactersList.
charactersList [2]["homeworld"] = "Jakku"
charactersList [2]["association"] = None
charactersList [2]["lightsaberColor"] = "Blue"
charactersList [2]["firstMovieAppearance"] = 7

# Print the Characters List of Dictionaries.
print ("Characters List of Dictionaries:")
print (charactersList)
print ()

# 5 of 5
# By the end of the last movie, Rey has made a lot of changes:
    # Becomes a Jedi
    # Creats a new lightsaber, which is yellow,
    # Makes a new home on Tatooine.
    # Adopts the last name Skywalker.
# Update your dictionary to reflect these changes.
charactersList [2]["association"] = "Jedi"
charactersList [2]["homeworld"] = "Tatooine"
charactersList [2]["lightsaberColor"] = "Yellow"
charactersList [2]["name"] = "Rey Skywalker"

# Print the Characters List of Dictionaries.
print ("Characters List of Dictionaries:")
print (charactersList)
print ()

# Activity 7 - Lightsaber Colors
# --------------------------------------------------
print ("Lightsaber Colors:")

# Iterate over the list of dictionaries using a loop.
for character in charactersList:

    # Print out each character's name AND lightsaber color (use string formatting)
    print ("{} has a {} lightsaber.".format (character ["name"], character ["lightsaberColor"].lower ()))

print ()

i = 0

while i < len (charactersList) - 1:

    print (charactersList [ i ]["name"])

    i = i + 1
# Out:
# Anakin first appeared in "Episode I - The Phantom Menace".
#
# Anakin Dictionary:
# {'name': 'Anakin Skywalker', 'homeworld': 'Tatooine', 'association': 'Jedi', 'lightsaberColor': 'Blue', 'firstMovieAppearance': 1}
#
# Anakin Dictionary:
# {'name': 'Darth Vader', 'homeworld': 'Mustafar', 'association': 'Sith', 'lightsaberColor': 'Red', 'firstMovieAppearance': 1}
#
# Anakin first appeared in "Episode I - The Phantom Menace".
#
# Characters List of Dictionaries:
# [{'name': 'Anakin Skywalker'}, {'name': 'Luke Skywalker'}, {'name': 'Rey'}]
#
# Character Names:
# Anakin Skywalker
# Luke Skywalker
# Rey
#
# Characters List of Dictionaries:
# [{'name': 'Darth Vader', 'homeworld': 'Mustafar', 'association': 'Sith', 'lightsaberColor': 'Red', 'firstMovieAppearance': 1}, {'name': 'Luke Skywalker'}, {'name': 'Rey'}]
#
# Characters List of Dictionaries:
# ...
